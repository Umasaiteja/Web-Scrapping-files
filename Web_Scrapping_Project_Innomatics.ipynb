# %% [markdown]
# # Importing the Libraries which is available in the Python

# %%
# pip install bs4

# %% [markdown]
# # load the required libraries

# %%
import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
import time

# %% [markdown]
# # Identify the URL

# %%
URL ='https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DAPPLE&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DMi'
URL
# Out:
# 'https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DAPPLE&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DMi'

# %%
page = requests.get(URL)

# %%
page.status_code
# Out:
# 200

# %%
'price -_30jeq3 _1_WHN1'

'ptitle = _4rR01T'

'rating _3LWZlK'


'overall _2kHMtA'


'fetures .col-7-12'
# Out:
# 'fetures .col-7-12'

# %%
page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flip
# ...

# %%
htmlcode = page.text

# %%
soup = BeautifulSoup(htmlcode)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
'price -_30jeq3 _1_WHN1'

'ptitle = _4rR01T'

'rating _3LWZlK'


'overall _2kHMtA'


'fetures .col-7-12'
# Out:
# 'fetures .col-7-12'

# %%
price = soup.find('div', attrs = {'class':'_30jeq3 _1_WHN1'})
price.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20200\1223710590.py in <module>
#       1 price = soup.find('div', attrs = {'class':'_30jeq3 _1_WHN1'})
# ----> 2 price.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
title = soup.find('div', attrs = {'class':'_4rR01T'})
title.text

# %%
rating = soup.find('div', attrs = {'class':'_3LWZlK'})
rating.text

# %%
overall = soup.find('div', attrs = {'class':'_2kHMtA'})
overall.text

# %%
price = soup.find_all('div', attrs = {'class':'_30jeq3 _1_WHN1'})
for i in price:
    print(i.text)

# %%
len(price)

# %%
title = soup.find_all('div', attrs = {'class':'_4rR01T'})
title

# %%
len(title)

# %%
features = soup.find_all('div', attrs = {'class':'fMghEO'})
#features

# %%
len(features)

# %%
overall = soup.find_all('div', attrs = {'class':'_3pLy-c row'})
len(overall)

# %%
type(overall)

# %%
rating = []
for i in range(len(overall)):
    r = overall[i].find('div', attrs = {'class':'_3LWZlK'})
    rating.append(r)
#rating

# %%
#overall

# %%
for i in range(1,3):
    url = f"https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DMi&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DAPPLE"
    print(url)

# %%
procuctnames = []
prices = []
ratings = []
features = []
# go throught the 23 pages
for i in range(1,55): 
    
    url = f"https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DMi&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DAPPLE"
    
    page = requests.get(URL)
    
    htmlcode = page.text
    
    soup = BeautifulSoup(htmlcode)
    
    price = soup.find_all('div', attrs = {'class':'_30jeq3 _1_WHN1'})
    title = soup.find_all('div', attrs = {'class':'_4rR01T'})
    rating = soup.find_all('div', attrs = {'class':'_3LWZlK'})
    feature = soup.find_all('div', attrs = {'class':'fMghEO'})
   
    
    for i in title:
        procuctnames.append(i.text)
        
    for i in price:
        prices.append(i.text)
        
    for i in rating:
        ratings.append(i.text)
    for i in price:
        features.append(i.text)

# %%
len(procuctnames), len(prices), len(features), len(ratings)

# %%
#soup.find_all('div', attrs={'class':'_2kHMtA row'})

# %%
productname = [] 
price = []
rating = []
features = []
pagenum = []
# go throught the 23 pages
for i in range(1,55): 
    start_time = time.time()
    URL = 'https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.brand%255B%255D%3DMi&p%5B%5D=facets.brand%255B%255D%3Drealme&p%5B%5D=facets.brand%255B%255D%3DAPPL&page={}'.format(i)
    page = requests.get(URL)
    pagecontent = page.text
    soup = BeautifulSoup(pagecontent)
    #<div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">realme Narzo 50 Pro 5G (Hyper Black, 128 GB)</div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">6 MB RAM | 128 GB ROM</li><li class="rgWa7D">16.26 cm (6.4 inch) Display</li><li class="rgWa7D">48MP Rear Camera</li><li class="rgWa7D">5000 mAh Battery</li><li class="rgWa7D">Dimensity 920 5G Processor Processor</li><li class="rgWa7D">12Months Brand Warranty</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹21,990</div></div><div class="_3tcB5a p8ucoS"><div><div class="_2Tpdn3" style="color: rgb(0, 0, 0); font-size: 12px; font-weight: 400;">Free delivery</div></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/fa_62673a.png"></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color: rgb(38, 165, 65); font-size: 14px; font-weight: 700;">Bank Offer</div></div></div></div></div>

    for x in soup.find_all('div', attrs={'class':'_3pLy-c row'}):
        pname = x.find('div', attrs = {'class':'_4rR01T'})
        cost = x.find('div', attrs = {'class':'_30jeq3 _1_WHN1'})
        rat = x.find('div', attrs = {'class':'_3LWZlK'})
        feature = x.find('div', attrs = {'class':'fMghEO'})
        
        
        if pname is None:
            productname.append(np.NaN)
        else:
            productname.append(pname.text)
            
        if cost is None:
            price.append(np.NaN)
        else:
            price.append(cost.text)
            
        if rat is None:
            rating.append(np.NaN)
        else:
            rating.append(rat.text)
            
        if feature is None:
            features.append(np.NaN)
        else:
            features.append(feature.text)
            
    pagenum.append(i)
    print('Page {} completed in {} seconds'.format(i, time.time()-start_time))

# %%
import pandas as pd
mobiles_df = pd.DataFrame({'ProductName':productname, 'Price':price, 'Rating': rating,'Features':features})#'PageNo': pagenum})

# %%
mobiles_df

# %%
mobiles_df.shape

# %%
mobiles_df.head()

# %%
mobiles_df.info()

# %%
# Save df to csv

mobiles_df.to_csv('mobilesData.csv', index= False)

# %%
mobiles_df.to_csv('mobiles.csv')

# %%
mobiles_df = pd.read_csv('mobilesData.csv')
mobiles_df.head(2)

# %%
mobiles_df.shape

# %%
mobiles_df['Features'][2]

# %%
mobiles_df['Features'][0]

# %%
mobiles_df['Features'][1]

# %%
#Configuratioon
#cpu, ram, storage, os

# %%
re.findall('^\w+', mobiles_df['Features'][2])

# %%
lambda x: re.findall('^\w+', x)

# %%
f = mobiles_df['Features'][7]
f

# %%
def g(x):
    return  re.findall('^\w+', x)

# %%
g = lambda x: re.findall('^\w+', x)

# %%
g(f)

# %%
mobiles_df['ProcessorName'] = mobiles_df['Features'].apply(lambda x: re.findall('^\w+', x))

# %%
mobiles_df.head()

# %%
def sq(n):
    return n**2

# %%
c = lambda x: x **3

# %%
c(3)

# %%
sq(3)

# %%
mobiles_df['Features'][2]

# %%
re.findall('[samsung| realme |mi][\w\s]+Processor', mobiles_df['Features'][2])

# %%
mobiles_df['ProcessorName'] = mobiles_df['Features'].apply(lambda x: re.findall('^\w+', x))

# %%
mobiles_df.head()

# %%
regex = '[samsung| A|mi][\w\s]+Processor'

mobiles_df['ProcessorDetails'] = mobiles_df['Features'].apply(lambda x: re.findall(regex, x))

# %%
mobiles_df.tail()

# %%
mobiles_df['Features'][7]

# %%
re.findall('[0-9][\s]*(?:GB)[\s\w]+RAM', mobiles_df['Features'][7])

# %%
regex = '[0-9][\s]*(?:GB)[\s\w]+RAM'

mobiles_df['RAM'] = mobiles_df['Features'].apply(lambda x: re.findall(regex, x))

# %%
mobiles_df.head()

# %% [markdown]
# # Screen Size

# %%
regex = r'[0-9.\s]+(?:cm|inch)'

mobiles_df['Screen_Size'] = mobiles_df['Features'].apply(lambda x:re.compile(regex).findall(x))

# %%
 mobiles_df.head()

# %%
mobiles_df['ProductName'][0]

# %% [markdown]
# # Brand

# %%
regex = r'^\w+'

mobiles_df['Brand'] = mobiles_df['ProductName'].apply(lambda x:re.findall(regex, x))

# %%
mobiles_df.head()

# %% [markdown]
# # EDA

# %%
# check for missing values

mobiles_df.isnull().sum()

# %% [markdown]
# # CLEANING DATA

# %%
mobiles_df.Brand[0], type(mobiles_df.Brand[0])

# %%
a = ['SAMSUNG']
a

# %%
''.join(a)

# %%
f = lambda x: ''.join(x)

# %%
f(['SAMSUNG'])

# %%
mobiles_df.Brand[0][0]

# %% [markdown]
# # convert the list item into string

# %%
''.join(mobiles_df.Brand[0])
type(''.join(mobiles_df.Brand[0]))

# %%
mobiles_df.columns

# %%
#mobiles_df['ProcessorName'], mobiles_df.ProcessorName

# %%
mobiles_df.ProcessorName = mobiles_df['ProcessorName'].apply(lambda x:''.join(x))

# %%
mobiles_df.ProcessorName

# %%
mobiles_df.head()

# %%
mobiles_df["Screen_Size"]

# %%
mobiles_df['ScreenSize_cm'] = mobiles_df.Screen_Size.apply(lambda x:x[0])
mobiles_df['ScreenSize_inch']  = mobiles_df.Screen_Size.apply(lambda x:x[1] if len(x)>1 else np.nan)

# %%
mobiles_df.head()

# %%
mobiles_df.info()

# %%
mobiles_df.Price[0]

# %%
mobiles_df.Price[0].replace('₹','')

# %%
mobiles_df.Price[0].replace('₹','').replace(',','')

# %%
int(mobiles_df.Price[0].replace('₹','').replace(',',''))

# %%
float(mobiles_df.Price[0].replace('₹','').replace(',',''))

# %%
mobiles_df['Price'] = float(mobiles_df.Price[0].replace('₹','').replace(',',''))

# %%
mobiles_df.head()

# %% [markdown]
# # Data Visualizations

# %%
mobiles_df.describe()
# Out:
#        ProductName Price Rating Features
# count            0     0      0        0
# unique           0     0      0        0
# top            NaN   NaN    NaN      NaN
# freq           NaN   NaN    NaN      NaN

# %%
data = np.random.randn(100)

# %%
data = pd.Series(data)
data = data.dropna()  # Remove NaNs
data = data[data != np.inf]  # Remove infinity values if any

# %%
sns.displot(data, kde=True)

# %%
sns.histplot(data, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# Example data
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [25, 35, 20, 20]  # Percentage for each category
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']  # Optional colors for the sections
explode = (0.1, 0, 0, 0)  # "Explode" the first slice (optional)

# Create pie chart
plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=90)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 40, 50]

# Create line graph
plt.plot(x, y, label='Line Graph', color='blue', marker='o')

# Adding labels and title
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple Line Graph')

# Show legend
plt.legend()

# Display the plot
plt.show()
